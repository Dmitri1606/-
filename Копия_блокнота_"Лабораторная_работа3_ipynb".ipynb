# %% [markdown]
# <a href="https://colab.research.google.com/github/Dmitri1606/-/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B03_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

data = pd.read_csv('sample_data/diamonds.csv')

data['cut'] = data['cut'].astype('category')
data['color'] = data['color'].astype('category')
data['clarity'] = data['clarity'].astype('category')
data['cut_cat']  = data['cut'].cat.codes
data['color_cat']  = data['color'].cat.codes
data['clarity_cat']  = data['clarity'].cat.codes

data = data.drop(['cut', 'color', 'clarity', data.columns[0]], axis='columns')

por = ['carat','depth','table','x','y','z','cut_cat','color_cat','clarity_cat','price']
data = data[por]

train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

features = ['carat','depth','table','x','y','z','cut_cat','color_cat','clarity_cat']
target = 'price'
x_train = train_data[features].values
x_test = test_data[features].values
y_train = train_data[target].values
y_test = test_data[target].values

mean = x_train.mean(axis=0)
std = x_train.std(axis=0)
x_train -= mean
x_train /= std
x_test -= mean
x_test /= std

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='relu'))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
history = model.fit(x_train,
                    y_train,
                    epochs=50,
                    validation_split=0.1,
                    verbose=0)
scores=model.evaluate(x_test,y_test, verbose=0)
print("средняя ошибка на тестовых данных:", round(scores[1],4))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-359902847.py in <cell line: 0>()
#       1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
# ----> 3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Dense
#       5
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py in <module>
#      47 _tf2.enable()
#      48
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/__init__.py in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
# ...

# %%
preg=model.predict(x_test).flatten()
print(preg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2275583582.py in <cell line: 0>()
# ----> 1 preg=model.predict(x_test).flatten()
#       2 print(preg)
#
# NameError: name 'x_test' is not defined

# %%
error=preg-y_test
plt.hist(error,bins=50)

# %%
test.head()

# %% [markdown]
# Перейдем к обучению датасета будем обрабатывать датасет с алмазами.

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('sample_data/diamonds.csv')
'''
# Разделение данных на тренировочную и тестовую выборки
train_data, test_data = train_test_split(data, test_size=0.2)

# Сохранение выборок в отдельные файлы (по желанию)
train_data.to_csv('train_data.csv', index=False)
test_data.to_csv('test_data.csv', index=False)

print("Тренировочная выборка:")
print(train_data.head())
print("\nТестовая выборка:")
print(test_data.head())
data.info()
data.rename(columns={data.columns[0]: 'id'}, inplace=True)
display(data["id"].unique())
'''

# %% [markdown]
# Подготовим датасет к обучению.

# %%
data.info()

# %%
data.isna().sum()

# %% [markdown]
# Посмотрим уникальные значения у столбцов cut,color,clarity для определения в какое состояние их можно перенести

# %%
display(data['cut'].unique())
display(data['color'].unique())
display(data['clarity'].unique())

# %% [markdown]
# Все три столбца  переводим в в категории и удаляем эти столбцы + начальный столбец,  который имеет номер алмаза.

# %%
data['cut'] = data['cut'].astype('category')
data['color'] = data['color'].astype('category')
data['clarity'] = data['clarity'].astype('category')
data['cut_cat']  = data['cut'].cat.codes
data['color_cat']  = data['color'].cat.codes
data['clarity_cat']  = data['clarity'].cat.codes

# del
data = data.drop(['cut', 'color', 'clarity',data.columns[0]], axis='columns')
data.head()

# %% [markdown]
# Зададим удобный порядк чтоб выделить таргет значение price

# %%
por = ['carat','depth','table','x','y','z','cut_cat','color_cat','clarity_cat','price']
data = data[por]
data.info()

# %% [markdown]
# Перейдем к разделению выборки.

# %%
train_data, test_data = train_test_split(data, test_size=0.2)

# %%
features = ['carat','depth','table','x','y','z','cut_cat','color_cat','clarity_cat']
target = 'price'
x_train = train_data[features].values
x_test = test_data[features].values
y_train = train_data[target].values
y_test = test_data[target].values

# %%
# Среднее значение
mean = x_train.mean(axis=0)
# Стандартное отклонение
std = x_train.std(axis=0)
#print(mean,std)
x_train -= mean
x_train /= std

x_test -= mean
x_test /= std

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='relu'))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
history = model.fit(x_train,
                    y_train,
                    epochs=50,
                    validation_split=0.1,
                    verbose=2)

# %%
scores=model.evaluate(x_test,y_test, verbose=1)
print("средняя ошибка на тестовых данных:", round(scores[1],4))

# %%
preg=model.predict(x_test).flatten()
print(preg)

# %%
error=preg-y_test
plt.hist(error,bins=50)
